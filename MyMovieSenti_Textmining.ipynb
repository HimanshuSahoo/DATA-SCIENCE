# %% [markdown]
# <a href="https://colab.research.google.com/github/HimanshuSahoo/DATA-SCIENCE/blob/main/MyMovieSenti_Textmining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing requests to extract content from a url
import requests   
# Beautifulsoup is for web scrapping...used to scrap specific content 
from bs4 import BeautifulSoup as bs 
import re 
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from textblob import TextBlob 
import pandas as pd

# %%
#!pip install textblob

# %%
def get_sentiment(review): 
    ''' 
    Utility function to classify sentiment of passed tweet 
    using textblob's sentiment method 
    '''
    # create TextBlob object of passed tweet text 
    analysis = TextBlob(review)
    # set sentiment 
    if analysis.sentiment.polarity > 0: 
        return 'positive'
    elif analysis.sentiment.polarity == 0: 
        return 'neutral'
    else: 
        return 'negative'

# %%
a = 'This was not a disgrace on the screen. Not An utter waste of time.'

get_sentiment(a)
# Out:
# 'negative'

# %% [markdown]
# ## Vader Lexicon

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/geethika/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sia = SentimentIntensityAnalyzer()
a = 'This was not a disgrace on the screen. Not An utter waste of time.'
sia.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.689, 'pos': 0.311, 'compound': 0.6072}

# %%
def get_vader_sentiment(review): 
    ''' 
    Utility function to classify sentiment of passed tweet 
    using textblob's sentiment method 
    '''
    sia = SentimentIntensityAnalyzer()
    # create TextBlob object of passed tweet text 
    analysis = sia.polarity_scores(review)
    # set sentiment 
    if analysis["compound"] > 0: 
        return 'positive'
    elif analysis["compound"] < 0: 
        return 'negative'
    else: 
        return 'neutral'

# %%
get_vader_sentiment(a)
# Out:
# 'positive'

# %% [markdown]
# # Rule Based Approach

# %%
# Reading reviews from a text file 
with open("iphone.txt","r",encoding='utf8') as input:
    iphone_reviews = input.read()
type(iphone_reviews)   
#iphone_reviews
# Out:
# str

# %%
# Joinining all the reviews into single paragraph 
#ip_rev_string = " ".join(iphone_reviews)
ip_rev_string = iphone_reviews
# Removing unwanted symbols incase if exists
ip_rev_string = re.sub("[^A-Za-z" "]+"," ",ip_rev_string).lower()
ip_rev_string = re.sub("[0-9" "]+"," ",ip_rev_string)


# words that contained in iphone 7 reviews
ip_reviews_words = ip_rev_string.split(" ")

stop_words = stopwords.words('english')
#stopwords = stop_words.split("\n")

ip_reviews_words = [w for w in ip_reviews_words if not w in stop_words]

# Joinining all the reviews into single paragraph 
ip_rev_string = " ".join(ip_reviews_words)

# %%
## Example
ip_rev_string
# Out:
# ' got iphone xr today product looks amazing unfortunately face id working glitch front camera portrait mode fine may happen fine pathetic service provided amazon apple firstly amazon takes responsibility product sold talking giant apple called market leaders went service centre running diagnostic solution came sending phone bangalore repair like sending new phone repair practical solution company provides charging bomb product also mention amazon authorised apple reseller guess issue escalated consumer court thank amazon apple android user life decided try iphone xr ios loving camera battery life absolute joy one month since got phone loving face id works flawlessly even dark dual sim function working like charm using vodafone primary sim jio e sim faced problem whatsoever camera better compared previous android phone camera support live photo disabled used supports video recording k fps camera also supports panorama mode gives amazing results selfie also good screen light flashlight taking selfie dark gamer play clash royale game works smoothly since phone latest processor sure problem even latest game loving ios far miss bottom keys found android ios fluid flaws os encountered got two minor ios updates purchase love updates distributed globally time one minor inconvenience found ios download apps mb forced connect wifi far found work around got adapted gesture navigation like something using ages face id absolute joy anything unlock phone hold phone phone unlocked mention face id works even dark lack notification led big inconvenience screen lights show notification every time hold phone regarding huge criticism got low screen resolution see problem hardly stream youtube k view youtube videos p without problem feel good enough service providers india never give enough data speed stream videos k regarding screen direct sunlight problem screen clearly visible even direct sunlight speakers one huge plus point devices speakers give surround sound like system love speakers phone regarding lack mm headphone jack see problem phone bundled earphone connects phone yeah wondering siri let tell google assistant much better one installed google assistant use google assistant siri google assistant practical rate google assistant siri scale best would rate siri google assistant overall extremely happy purchase got rupees gb version anyone wants give ios try highly recommend iphone xr latest devices apple reasonable price one thing pushed ios apple gives os update years delay os updates android pain waiting manufacturer release update google outs update hope simple review iphone xr helped thank reading cheers delivered phone work immediately removing box able return need first check apple apple service told phone lying without charge since months hence battery failed leave phone apple repairs waiting replace battery please answer run around sub par quality device shipped dead phone last time ever purchase phone online month since started using iphone xr experience awesome excellent battery life smooth operating system dual sim functionality best features iphone spent many days decide colour opted white happy coral also good colour option bought wife issue bothering time taken charge phone need opt overnight charging extremely happy purchase best mobile favourite nice xr amazing futures best camera thanks amazon '

# %%
#temp = ["this","is","awsome","Data","Science"]
#[i for i in temp if i not in "is"]

# %%
# WordCloud can be performed on the string inputs. That is the reason we have combined 
# entire reviews into single paragraph
# Simple word cloud


wordcloud_ip = WordCloud(
                      background_color='black',
                      max_words = 100
                     ).generate(ip_rev_string)

plt.imshow(wordcloud_ip)
plt.axis("off")
plt.show()

# %%
# positive words # Choose the path for +ve words stored in system
with open("positive-words.txt","r") as pos:
  poswords = pos.read().split("\n")
  
poswords = poswords[36:]


# negative words  Choose path for -ve words stored in system
with open("negative-words.txt","r") as neg:
  negwords = neg.read().split("\n")

negwords = negwords[37:]

# %%
# negative word cloud
# Choosing the only words which are present in negwords
ip_neg_in_neg = " ".join ([w for w in ip_reviews_words if w in negwords])

wordcloud_neg_in_neg = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(ip_neg_in_neg)

plt.imshow(wordcloud_neg_in_neg)
plt.axis("off")

plt.show()

# %%
# Positive word cloud
# Choosing the only words which are present in positive words
ip_pos_in_pos = " ".join ([w for w in ip_reviews_words if w in poswords])
wordcloud_pos_in_pos = WordCloud(
                      background_color='black',
                      width=1800,
                      height=1400
                     ).generate(ip_pos_in_pos)
plt.imshow(wordcloud_pos_in_pos)
plt.axis("off")
plt.show()

# %%
len(ip_pos_in_pos)
# Out:
# 335

# %%
len(ip_neg_in_neg)
# Out:
# 222

# %%
len(ip_reviews_words)
# Out:
# 506

# %%
335/506
# Out:
# 0.6620553359683794

# %%
222/506
# Out:
# 0.43873517786561267

# %% [markdown]
# ## Amazon Reviews

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('amazonreviews.tsv', sep='\t')
df.head()
# Out:
#   label                                             review
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...

# %%
df['label'].value_counts()
# Out:
# neg    5097
# pos    4903
# Name: label, dtype: int64

# %%
sid.polarity_scores(df.loc[0]['review'])
# Out:
# {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'compound': 0.9454}

# %%
df['scores'] = df['review'].apply(lambda review: sid.polarity_scores(review))
df.head()
# Out:
#   label                                             review  \
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...
#
#                                               scores
# 0  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...
# 1  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...
# 2  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...
# 3  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...

# %%
df['compound']  = df['scores'].apply(lambda scores: scores['compound'])
df.head()
# Out:
#   label                                             review  \
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...
#
#                                               scores  compound
# 0  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...    0.9454
# 1  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...    0.8957
# 2  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...    0.9858
# 3  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...    0.9814
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...    0.9781

# %%
df['scores'][0]['compound']
# Out:
# 0.9454

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')

# %%
df.head()
# Out:
#   label                                             review  \
# 0   pos  Stuning even for the non-gamer: This sound tra...
# 1   pos  The best soundtrack ever to anything.: I'm rea...
# 2   pos  Amazing!: This soundtrack is my favorite music...
# 3   pos  Excellent Soundtrack: I truly like this soundt...
# 4   pos  Remember, Pull Your Jaw Off The Floor After He...
#
#                                               scores  compound comp_score
# 0  {'neg': 0.088, 'neu': 0.669, 'pos': 0.243, 'co...    0.9454        pos
# 1  {'neg': 0.018, 'neu': 0.837, 'pos': 0.145, 'co...    0.8957        pos
# 2  {'neg': 0.04, 'neu': 0.692, 'pos': 0.268, 'com...    0.9858        pos
# 3  {'neg': 0.09, 'neu': 0.615, 'pos': 0.295, 'com...    0.9814        pos
# 4  {'neg': 0.0, 'neu': 0.746, 'pos': 0.254, 'comp...    0.9781        pos

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_score(df['label'],df['comp_score'])
# Out:
# 0.7092

# %%
print(classification_report(df['label'],df['comp_score']))
# Out:
#               precision    recall  f1-score   support
#
#          neg       0.86      0.51      0.64      5097
#          pos       0.64      0.91      0.75      4903
#
#     accuracy                           0.71     10000
#    macro avg       0.75      0.71      0.70     10000
# weighted avg       0.75      0.71      0.70     10000

# %%
print(confusion_matrix(df['label'],df['comp_score']))
# Out:
# [[2623 2474]
#  [ 434 4469]]
